# %%
import numpy as np
import pandas as pd
import os
from itertools import chain, combinations

# %%
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s) + 1))

# %%
df = pd.read_csv('final.csv')
df
# Out:
#      Unnamed: 0          County_Name population pop_below_poverty  \
# 0             0      Accomack County     32,325             6,141
# 1             1     Albemarle County    100,293             9,142
# 2             2     Alleghany County     14,830             2,925
# 3             3        Amelia County     12,861             1,375
# 4             4       Amherst County     30,994             4,327
# ..          ...                  ...        ...               ...
# 100         100      Portsmouth city     91,156            15,312
# 101         101        Richmond city    216,099            50,200
# 102         102         Roanoke city     97,449            20,240
# 103         103         Suffolk city     89,418             9,267
# 104         104  Virginia Beach city    439,531            32,183
#
#     pct_below_poverty  Earnings by place of work  \
# 0              19.00%                    1119986
# 1               9.10%                    8516598
# 2              19.70%                     501496
# 3              10.70%                     170244
# 4              14.00%                     469950
# ..                ...                        ...
# 100            16.80%                    4430689
# 101            23.20%                   14931755
# 102            20.80%                    4663469
# 103            10.40%                    2388109
# 104             7.30%                   14300231
#
#      Employee and self-employed contributions for government social insurance  \
# 0                                                67460
# 1                                               503727
# 2                                                38180
# 3                                                13804
# 4                                                38937
# ..                                                 ...
# 100                                             246547
# 101                                             881642
# 102                                             291624
# 103                                             156009
# 104                                             867009
#
#      Employer contributions for employee pension and insurance funds 8  \
# 0                                               181644
# 1                                              1099244
# 2                                                65423
# 3                                                19010
# 4                                                64076
# ..                                                 ...
# 100                                             849649
# 101                                            1780724
# 102                                             554444
# 103                                             292172
# 104                                            1825039
#
#      Employer contributions for government social insurance  \
# 0                                               129706
# 1                                               847618
# 2                                                58456
# 3                                                15622
# 4                                                49606
# ..                                                 ...
# 100                                             514532
# 101                                            1531298
# 102                                             539960
# 103                                             262554
# 104                                            1544850
#
#      Equals: Net earnings by place of residence  ...  \
# 0                                        858335  ...
# 1                                       6196611  ...
# 2                                        412284  ...
# 3                                        353626  ...
# 4                                        661161  ...
# ..                                          ...  ...
# 100                                     2223456  ...
# 101                                     7437338  ...
# 102                                     2261475  ...
# 103                                     3043349  ...
# 104                                    16247369  ...
#
#      Employment_Transportation_Equipment_Manufacturing  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 100                                              319.0
# 101                                                9.0
# 102                                              349.0
# 103                                                NaN
# 104                                              415.0
#
#      Employment_Transportation_and_Warehousing  \
# 0                                        114.0
# 1                                        682.0
# 2                                         18.0
# 3                                        104.0
# 4                                        282.0
# ..                                         ...
# 100                                     1807.0
# 101                                     4809.0
# 102                                     4007.0
# 103                                     2375.0
# 104                                     1943.0
#
#      Employment_Truck_Transportation  Employment_Utilities  \
# 0                               57.0                 168.0
# 1                               65.0                   NaN
# 2                               15.0                   NaN
# 3                               41.0                   NaN
# 4                              228.0                   NaN
# ..                               ...                   ...
# 100                            365.0                  66.0
# 101                           2326.0                4678.0
# 102                            837.0                 674.0
# 103                            258.0                   NaN
# 104                            656.0                 614.0
#
#      Employment_Warehousing_and_Storage  \
# 0                                   NaN
# 1                                   9.0
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 100                                 NaN
# 101                               220.0
# 102                               802.0
# 103                              1982.0
# 104                                84.0
#
#      Employment_Waste_Management_and_Remediation_Services  \
# 0                                                  NaN
# 1                                                 76.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 100                                              236.0
# 101                                              488.0
# 102                                              153.0
# 103                                               32.0
# 104                                              312.0
#
#      Employment_Water_Transportation  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 100                              NaN
# 101                              NaN
# 102                              NaN
# 103                              NaN
# 104                              NaN
#
#      Employment_Wholesale_Electronic_Markets_and_Agents_and_Brokers  \
# 0                                                  NaN
# 1                                                 24.0
# 2                                                  NaN
# 3                                                  3.0
# 4                                                  NaN
# ..                                                 ...
# 100                                                3.0
# 101                                               42.0
# 102                                               39.0
# 103                                               16.0
# 104                                              253.0
#
#      Employment_Wholesale_Trade  Employment_Wood_Product_Manufacturing
# 0                         130.0                                    NaN
# 1                         447.0                                  154.0
# 2                          27.0                                   96.0
# 3                         117.0                                  117.0
# 4                         175.0                                   48.0
# ..                          ...                                    ...
# 100                       594.0                                    NaN
# 101                      4202.0                                   43.0
# 102                      3244.0                                    NaN
# 103                      1207.0                                    NaN
# 104                      3857.0                                   41.0
#
# [105 rows x 128 columns]

# %%
cols = ['pop_below_poverty','pct_below_povery']

# %%
x = powerset(df)

# %%
[i for i in powerset(df.loc[:,df.columns]) if len(i) < 10]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 [i for i in powerset(df.loc[:,df.columns]) if len(i) < 10]
#
# Input In [17], in <listcomp>(.0)
# ----> 1 [i for i in powerset(df.loc[:,df.columns]) if len(i) < 10]
#
# MemoryError:
